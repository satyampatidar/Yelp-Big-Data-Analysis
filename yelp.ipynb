# %% [markdown]
# <a href="https://colab.research.google.com/github/satyampatidar/Yelp_Dataset/blob/main/yelp.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# importing packages 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# load json file using pandas 
df_business = pd.read_json('/content/drive/MyDrive/yelp_dataset2/yelp_academic_dataset_business.json', lines = True) 
df_checkin = pd.read_json('/content/drive/MyDrive/yelp_dataset2/yelp_academic_dataset_business.json', lines = True) 
df_review = pd.read_json('/content/drive/MyDrive/yelp_dataset2/yelp_academic_dataset_business.json', lines = True) 
df_tip = pd.read_json('/content/drive/MyDrive/yelp_dataset2/yelp_academic_dataset_business.json', lines = True) 
df_user = pd.read_json('/content/drive/MyDrive/yelp_dataset2/yelp_academic_dataset_business.json', lines = True)
# Out:
#                    business_id  ...                                              hours
# 0       f9NumwFMBDn751xgFiRbNA  ...  {'Monday': '10:0-18:0', 'Tuesday': '11:0-20:0'...
# 1       Yzvjg0SayhoZgCljUJRF9Q  ...                                               None
# 2       XNoUzKckATkOD1hP6vghZg  ...                                               None
# 3       6OAZjbxqM5ol29BuHsil3w  ...  {'Monday': '7:0-16:0', 'Tuesday': '7:0-16:0', ...
# 4       51M2Kk903DFYI6gnB5I6SQ  ...  {'Monday': '0:0-0:0', 'Tuesday': '9:0-16:0', '...
# ...                        ...  ...                                                ...
# 209388  9Q0fPWAjUweoFDk0kafuzQ  ...  {'Monday': '11:0-22:0', 'Tuesday': '11:0-22:0'...
# 209389  PotiAhtDMYMNsJCzV0oLAw  ...                                               None
# 209390  SYa2j1boLF8DcGVOYfHPcA  ...  {'Monday': '11:0-22:0', 'Tuesday': '11:0-22:0'...
# 209391  RSSIsgO00OuWQTRoITacpA  ...  {'Monday': '0:0-0:0', 'Tuesday': '7:0-19:0', '...
# ...

# %%
# view data 
print(df_business)
print(df_checkin)
print(df_review)
print(df_tip)
print(df_user)
# Out:
#                    business_id  ...                                              hours
# 0       f9NumwFMBDn751xgFiRbNA  ...  {'Monday': '10:0-18:0', 'Tuesday': '11:0-20:0'...
# 1       Yzvjg0SayhoZgCljUJRF9Q  ...                                               None
# 2       XNoUzKckATkOD1hP6vghZg  ...                                               None
# 3       6OAZjbxqM5ol29BuHsil3w  ...  {'Monday': '7:0-16:0', 'Tuesday': '7:0-16:0', ...
# 4       51M2Kk903DFYI6gnB5I6SQ  ...  {'Monday': '0:0-0:0', 'Tuesday': '9:0-16:0', '...
# ...                        ...  ...                                                ...
# 209388  9Q0fPWAjUweoFDk0kafuzQ  ...  {'Monday': '11:0-22:0', 'Tuesday': '11:0-22:0'...
# 209389  PotiAhtDMYMNsJCzV0oLAw  ...                                               None
# 209390  SYa2j1boLF8DcGVOYfHPcA  ...  {'Monday': '11:0-22:0', 'Tuesday': '11:0-22:0'...
# 209391  RSSIsgO00OuWQTRoITacpA  ...  {'Monday': '0:0-0:0', 'Tuesday': '7:0-19:0', '...
# ...

# %%
# Convert to CSV
df_business.to_csv("business.csv",index = False)
df_checkin.to_csv("checkin.csv",index = False)
df_review.to_csv("review.csv", index = False)
df_tip.to_csv("tip.csv", index = False)
df_user.to_csv("user.csv", index = False)

# %%
# LOADING THE DATASET AND SEEING THE DETAILS
data = pd.read_csv('/content/business.csv')
# SHAPE OF THE DATASET
print("Shape of the dataset:")
print(data.shape)
print(data.head())
# DATASET SUMMARY
data.describe(include='all')
# Out:
# Shape of the dataset:
# (209393, 14)
#               business_id  ...                                              hours
# 0  f9NumwFMBDn751xgFiRbNA  ...  {'Monday': '10:0-18:0', 'Tuesday': '11:0-20:0'...
# 1  Yzvjg0SayhoZgCljUJRF9Q  ...                                                NaN
# 2  XNoUzKckATkOD1hP6vghZg  ...                                                NaN
# 3  6OAZjbxqM5ol29BuHsil3w  ...  {'Monday': '7:0-16:0', 'Tuesday': '7:0-16:0', ...
# 4  51M2Kk903DFYI6gnB5I6SQ  ...  {'Monday': '0:0-0:0', 'Tuesday': '9:0-16:0', '...
#
# [5 rows x 14 columns]
#                    business_id  ...                                              hours
# count                   209393  ...                                             164550
# unique                  209393  ...                                              57640
# top     0MV_T5y-UjGaYg_xlOq0lQ  ...  {'Monday': '0:0-0:0', 'Tuesday': '0:0-0:0', 'W...
# ...

# %%
plt.figure(figsize=(12,4))
ax = sns.countplot(data['stars'])
plt.title('Distribution of rating');
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
